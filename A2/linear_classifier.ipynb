# %% [markdown]
# # EECS 498-007/598-005 Assignment 2-1: Linear Classifiers
#
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Justin JOHNSON, #12345678

# %% [markdown]
# **Your Answer:**
# Your NAME, #XXXXXXXX

# %% [markdown]
# ## Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as Assignment 1. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['two_layer_net.ipynb', 'eecs598', 'two_layer_net.py', 'linear_classifier.py', 'linear_classifier.ipynb', 'challenge_problem.ipynb']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A2 folder, then '2020FA/A2'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A2'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'A2'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['two_layer_net.ipynb', 'challenge_problem.ipynb', 'two_layer_net.py', 'svm_best_model.pt', 'linear_classifier.py', 'eecs598', '__pycache__', 'linear_classifier.ipynb']

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from linear_classifier.py!
# ```
#
# as well as the last edit time for the file `linear_classifier.py`.

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from linear_classifier import hello_linear_classifier
hello_linear_classifier()

linear_classifier_path = os.path.join(GOOGLE_DRIVE_PATH, 'linear_classifier.py')
linear_classifier_edit_time = time.ctime(os.path.getmtime(linear_classifier_path))
print('linear_classifier.py last edited on %s' % linear_classifier_edit_time)
# Out:
# Hello from linear_classifier.py!
# linear_classifier.py last edited on Mon Dec  8 14:59:14 2025

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Setup code
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import eecs598
import torch
import torchvision
import matplotlib.pyplot as plt
import statistics
import random
import time
import math
# %matplotlib inline


plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16

# %% [markdown]
# Starting in this assignment, we will use the GPU to accelerate our computation. Run this cell to make sure you are using a GPU.

# %%
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# ## Load the CIFAR-10 dataset
# Then, we will first load the CIFAR-10 dataset, same as knn. The utility function `eecs598.data.preprocess_cifar10()` returns the entire CIFAR-10 dataset as a set of six **Torch tensors**:
#
# - `X_train` contains all training images (real numbers in the range $[0, 1]$)
# - `y_train` contains all training labels (integers in the range $[0, 9]$)
# - `X_val` contains all validation images
# - `y_val` contains all validation labels
# - `X_test` contains all test images
# - `y_test` contains all test labels
#
# In this notebook we will use the **bias trick**: By adding an extra constant feature of ones to each image, we avoid the need to keep track of a bias vector; the bias will be encoded as the part of the weight matrix that interacts with the constant ones in the input.
#
# In the `two_layer_net.ipynb` notebook that follows this one, we will not use the bias trick.
#
# We can learn more about the `eecs598.data.preprocess_cifar10` function by invoking the `help` command:

# %%
import eecs598
help(eecs598.data.preprocess_cifar10)
# Out:
# Help on function preprocess_cifar10 in module eecs598.data:
#
# preprocess_cifar10(cuda=True, show_examples=True, bias_trick=False, flatten=True, validation_ratio=0.2, dtype=torch.float32)
#     Returns a preprocessed version of the CIFAR10 dataset, automatically
#     downloading if necessary. We perform the following steps:
#
#     (0) [Optional] Visualize some images from the dataset
#     (1) Normalize the data by subtracting the mean
#     (2) Reshape each image of shape (3, 32, 32) into a vector of shape (3072,)
#     (3) [Optional] Bias trick: add an extra dimension of ones to the data
#     (4) Carve out a validation set from the training set
#
#     Inputs:
#     - cuda: If true, move the entire dataset to the GPU
#     - validation_ratio: Float in the range (0, 1) giving the fraction of the train
#       set to reserve for validation
#     - bias_trick: Boolean telling whether or not to apply the bias trick
#     - show_examples: Boolean telling whether or not to visualize data samples
#     - dtype: Optional, data type of the input image X
#
#     Returns a dictionary with the following keys:
#     - 'X_train': `dtype` tensor of shape (N_train, D) giving training images
#     - 'X_val': `dtype` tensor of shape (N_val, D) giving val images
#     - 'X_test': `dtype` tensor of shape (N_test, D) giving test images
#     - 'y_train': int64 tensor of shape (N_train,) giving training labels
#     - 'y_val': int64 tensor of shape (N_val,) giving val labels
#     - 'y_test': int64 tensor of shape (N_test,) giving test labels
#
#     N_train, N_val, and N_test are the number of examples in the train, val, and
#     test sets respectively. The precise values of N_train and N_val are determined
#     by the input parameter validation_ratio. D is the dimension of the image data;
#     if bias_trick is False, then D = 32 * 32 * 3 = 3072;
#     if bias_trick is True then D = 1 + 32 * 32 * 3 = 3073.

# %% [markdown]
# We can now run the `eecs598.data.preprocess` function to get our data:

# %%
# Invoke the above function to get our data.
import eecs598

eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(bias_trick=True, dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# 100%|██████████| 170M/170M [00:08<00:00, 20.3MB/s]
# Train data shape:  torch.Size([40000, 3073])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3073])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3073])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# # SVM Classifier
#
# In this section, you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights
#
# In Assignment 2, you SHOULD NOT use ".to()" or ".cuda()" in each implementation block. Otherwise, your implementation would gives you an error in Autograder end.

# %% [markdown]
# First, we will test the naive version of svm loss in `linear_classifier.py`. Let's first try the naive implementation of the loss we provided for you. You will get 9.000197. (Note: we've provided the `loss` part of the `svm_loss_naive` function, so you don't need to re-implement in `svm_loss_naive`. However, if your loss value doesn't match, then please report this to [Piazza](https://piazza.com/class/kxtai72amx34p0))

# %%
import eecs598
from linear_classifier import svm_loss_naive

eecs598.reset_seed(0)
# generate a random SVM weight tensor of small numbers
W = torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device) * 0.0001

loss, _grad_ = svm_loss_naive(W, data_dict['X_val'], data_dict['y_val'], 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 9.000888

# %% [markdown]
# The `_grad_` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`, by filing out the TODO blocks. You will find it helpful to interweave your new code inside the existing function.
#
# To check that you have implemented the gradient correctly, we will use **numeric gradient checking**: we will use a finite differences approach to numerically estimate the gradient of the forward pass, and compare this numeric gradient to the analytic gradient that you implemented.
#
# We have provided a function `eecs598.grad.grad_check_sparse` to help with numeric gradient checking. You can learn more about this function using the `help` command:

# %%
import eecs598
help(eecs598.grad.grad_check_sparse)
# Out:
# Help on function grad_check_sparse in module eecs598.grad:
#
# grad_check_sparse(f, x, analytic_grad, num_checks=10, h=1e-07)
#     Utility function to perform numeric gradient checking. We use the centered
#     difference formula to compute a numeric derivative:
#
#     f'(x) =~ (f(x + h) - f(x - h)) / (2h)
#
#     Rather than computing a full numeric gradient, we sparsely sample a few
#     dimensions along which to compute numeric derivatives.
#
#     Inputs:
#     - f: A function that inputs a torch tensor and returns a torch scalar
#     - x: A torch tensor of the point at which to evaluate the numeric gradient
#     - analytic_grad: A torch tensor giving the analytic gradient of f at x
#     - num_checks: The number of dimensions along which to check
#     - h: Step size for computing numeric derivatives

# %% [markdown]
# Now run the following to perform numeric gradient checking on the gradients of your SVM loss. You should see relative errors less than `1e-5`.

# %%
import eecs598
import linear_classifier
from importlib import reload
reload(linear_classifier)
from linear_classifier import svm_loss_naive

# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Use a random W and a minibatch of data from the val set for gradient checking
# For numeric gradient checking it is a good idea to use 64-bit floating point
# numbers for increased numeric precision; however when actually training models
# we usually use 32-bit floating point numbers for increased speed.
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
batch_size = 64
X_batch = data_dict['X_val'][:batch_size]
y_batch = data_dict['y_val'][:batch_size]

# Compute the loss and its gradient at W.
# YOUR_TURN: implement the gradient part of 'svm_loss_naive' function in "linear_classifier.py"
_, grad = svm_loss_naive(W, X_batch, y_batch, reg=0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should
# match almost exactly along all dimensions.
f = lambda w: svm_loss_naive(w, X_batch, y_batch, reg=0.0)[0]
grad_numerical = eecs598.grad.grad_check_sparse(f, W, grad)
# Out:
# numerical: 0.031599 analytic: 0.031599, relative error: 3.139148e-07
# numerical: 0.111444 analytic: 0.111444, relative error: 9.893848e-10
# numerical: 0.011204 analytic: 0.011204, relative error: 1.003052e-06
# numerical: -0.046128 analytic: -0.046128, relative error: 8.157190e-08
# numerical: 0.071948 analytic: 0.071948, relative error: 1.000117e-07
# numerical: 0.025688 analytic: 0.025688, relative error: 1.051337e-06
# numerical: 0.185388 analytic: 0.185388, relative error: 7.039118e-09
# numerical: -0.021740 analytic: -0.021740, relative error: 3.369463e-07
# numerical: -0.159613 analytic: -0.159613, relative error: 6.416943e-08
# numerical: 0.092690 analytic: 0.092690, relative error: 1.748534e-07

# %% [markdown]
# Let's do the gradient check once again with regularization turned on. (You didn't forget the regularization gradient, did you?)
#
# You should see relative errors less than `1e-5`.

# %%
import eecs598
from linear_classifier import svm_loss_naive

# Use a minibatch of data from the val set for gradient checking
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
batch_size = 64
X_batch = data_dict['X_val'][:batch_size]
y_batch = data_dict['y_val'][:batch_size]

# Compute the loss and its gradient at W.
# YOUR_TURN: check your 'svm_loss_naive' implementation with different 'reg'
_, grad = svm_loss_naive(W, X_batch, y_batch, reg=1e3)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should
# match almost exactly along all dimensions.
f = lambda w: svm_loss_naive(w, X_batch, y_batch, reg=1e3)[0]
grad_numerical = eecs598.grad.grad_check_sparse(f, W, grad)
# Out:
# numerical: 0.124849 analytic: 0.124849, relative error: 6.251581e-08
# numerical: 0.168915 analytic: 0.168915, relative error: 5.957873e-09
# numerical: 0.148752 analytic: 0.148752, relative error: 8.733009e-08
# numerical: -0.024936 analytic: -0.024936, relative error: 6.470254e-08
# numerical: -0.008570 analytic: -0.008570, relative error: 7.174549e-07
# numerical: -0.103155 analytic: -0.103155, relative error: 2.498757e-07
# numerical: -0.335573 analytic: -0.335573, relative error: 4.472387e-09
# numerical: -0.222176 analytic: -0.222176, relative error: 4.264915e-08
# numerical: 0.681163 analytic: 0.681163, relative error: 1.235571e-08
# numerical: -0.004090 analytic: -0.004089, relative error: 4.327973e-06

# %% [markdown]
# Now, let's implement vectorized version of SVM: `svm_loss_vectorized`. It should compute the same inputs and outputs as the naive version before, but it should involve **no explicit loops**.
#
# Let's first check the speed and performance bewteen the non-vectorized and the vectorized version. You should see a 15-120x speedup. PyTorch does some extra setup the first time you run CUDA code, so **you may need to run this cell more than once to see the desired speedup**.
#
# (Note: It may have some difference, but should be less than 1e-6)

# %%
import eecs598
import linear_classifier
reload(linear_classifier)
from linear_classifier import svm_loss_naive, svm_loss_vectorized

# Use random weights and a minibatch of val data for gradient checking
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]
reg = 0.000005

# Run and time the naive version
torch.cuda.synchronize()
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_naive = 1000.0 * (toc - tic)
print('Naive loss: %e computed in %.2fms' % (loss_naive, ms_naive))

# Run and time the vectorized version
torch.cuda.synchronize()
tic = time.time()
# YOUR_TURN: implement the loss part of 'svm_loss_vectorized' function in "linear_classifier.py"
loss_vec, _ = svm_loss_vectorized(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_vec = 1000.0 * (toc - tic)
print('Vectorized loss: %e computed in %.2fms' % (loss_vec, ms_vec))

# The losses should match but your vectorized implementation should be much faster.
print('Difference: %.2e' % (loss_naive - loss_vec))
print('Speedup: %.2fX' % (ms_naive / ms_vec))
# Out:
# Naive loss: 9.002394e+00 computed in 206.11ms
# Vectorized loss: 9.002394e+00 computed in 189.24ms
# Difference: 1.53e-09
# Speedup: 1.09X

# %% [markdown]
# Then, let's compute the gradient of the loss function. We can check the difference of gradient as well. (The error should be less than 1e-6)
#
# Now implement a vectorized version of the gradient computation in `svm_loss_vectorize` above. Run the cell below to compare the gradient of your naive and vectorized implementations. The difference between the gradients should be less than `1e-6`, and the vectorized version should run 15-120x faster.

# %%
# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
import torch
import linear_classifier
from importlib import reload
reload(linear_classifier)
import eecs598
from linear_classifier import svm_loss_naive, svm_loss_vectorized

# Use random weights and a minibatch of val data for gradient checking
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]
reg = 0.000005

# Run and time the naive version
torch.cuda.synchronize()
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_batch, y_batch, 0.000005)
torch.cuda.synchronize()
toc = time.time()
ms_naive = 1000.0 * (toc - tic)
print('Naive loss and gradient: computed in %.2fms' % ms_naive)

# Run and time the vectorized version
torch.cuda.synchronize()
tic = time.time()
# YOUR_TURN: implement the gradient part of 'svm_loss_vectorized' function in "linear_classifier.py"
_, grad_vec = svm_loss_vectorized(W, X_batch, y_batch, 0.000005)
torch.cuda.synchronize()
toc = time.time()
ms_vec = 1000.0 * (toc - tic)
print('Vectorized loss and gradient: computed in %.2fms' % ms_vec)
print(grad_vec)
print(grad_naive)

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a tensor, so
# we use the Frobenius norm to compare them.
grad_difference = torch.norm(grad_naive - grad_vec, p='fro')
print('Gradient difference: %.2e' % grad_difference)
print('Speedup: %.2fX' % (ms_naive / ms_vec))
# Out:
# Naive loss and gradient: computed in 222.95ms
# Vectorized loss and gradient: computed in 3.31ms
# tensor([[-0.0513, -0.0013,  0.0836,  ...,  0.0914,  0.0117, -0.3603],
#         [-0.0554, -0.0097,  0.0642,  ...,  0.0854,  0.0134, -0.3436],
#         [-0.0596, -0.0269,  0.0530,  ...,  0.0767,  0.0158, -0.3409],
#         ...,
#         [-0.0633,  0.0553, -0.0258,  ..., -0.0437,  0.0998, -0.1889],
#         [-0.0783,  0.0556,  0.0024,  ..., -0.0235,  0.0768, -0.2153],
#         [ 0.5313, -0.0938,  0.1406,  ..., -0.1719,  0.0625, -0.6406]],
#        device='cuda:0', dtype=torch.float64)
# tensor([[-0.0513, -0.0013,  0.0836,  ...,  0.0914,  0.0117, -0.3603],
#         [-0.0554, -0.0097,  0.0642,  ...,  0.0854,  0.0134, -0.3436],
#         [-0.0596, -0.0269,  0.0530,  ...,  0.0767,  0.0158, -0.3409],
#         ...,
#         [-0.0633,  0.0553, -0.0258,  ..., -0.0437,  0.0998, -0.1889],
#         [-0.0783,  0.0556,  0.0024,  ..., -0.0235,  0.0768, -0.2153],
#         [ 0.5313, -0.0938,  0.1406,  ..., -0.1719,  0.0625, -0.6406]],
#        device='cuda:0', dtype=torch.float64)
# Gradient difference: 1.87e-14
# Speedup: 67.35X

# %% [markdown]
# Now that we have an efficient vectorized implementation of the SVM loss and its gradient, we can implement a training pipeline for linear classifiers.
#
# Please complete the implementation of `train_linear_classifier` in `linear_classifer.py`.

# %% [markdown]
# Once you have implemented the training function, run the following cell to train a linear classifier using some default hyperparameters:
#
# (You should see a final loss close to 9.0, and your training loop should run in about two seconds)

# %%
import eecs598
import linear_classifier
reload(linear_classifier)
from linear_classifier import svm_loss_vectorized, train_linear_classifier

# fix random seed before we perform this operation
eecs598.reset_seed(0)

torch.cuda.synchronize()
tic = time.time()

# YOUR_TURN: Implement how to construct the batch,
#            and how to update the weight in 'train_linear_classifier'
W, loss_hist = train_linear_classifier(svm_loss_vectorized, None,
                                       data_dict['X_train'],
                                       data_dict['y_train'],
                                       learning_rate=3e-11, reg=2.5e4,
                                       num_iters=1500, verbose=True)

torch.cuda.synchronize()
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 9.000019
# iteration 100 / 1500: loss 8.999997
# iteration 200 / 1500: loss 9.000013
# iteration 300 / 1500: loss 9.000001
# iteration 400 / 1500: loss 9.000014
# iteration 500 / 1500: loss 9.000007
# iteration 600 / 1500: loss 9.000008
# iteration 700 / 1500: loss 9.000006
# iteration 800 / 1500: loss 9.000009
# iteration 900 / 1500: loss 9.000009
# iteration 1000 / 1500: loss 9.000007
# iteration 1100 / 1500: loss 9.000026
# iteration 1200 / 1500: loss 9.000024
# iteration 1300 / 1500: loss 9.000007
# iteration 1400 / 1500: loss 9.000015
# That took 2.553728s

# %% [markdown]
# A useful debugging strategy is to plot the loss as a function of iteration number. In this case it seems our hyperparameters are not good, since the training loss is not decreasing very fast.

# %%
plt.plot(loss_hist, 'o')
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# Then, let's move on to the prediction stage. We can evaluate the performance our trained model on both the training and validation set. You should see validation accuracy less than 20%.

# %%
import eecs598
reload(linear_classifier)
from linear_classifier import predict_linear_classifier

# fix random seed before we perform this operation
eecs598.reset_seed(0)

# evaluate the performance on both the training and validation set
# YOUR_TURN: Implement how to make a prediction with the trained weight
#            in 'predict_linear_classifier'
y_train_pred = predict_linear_classifier(W, data_dict['X_train'])
train_acc = 100.0 * (data_dict['y_train'] == y_train_pred).double().mean().item()
print('Training accuracy: %.2f%%' % train_acc)

y_val_pred = predict_linear_classifier(W, data_dict['X_val'])
val_acc = 100.0 * (data_dict['y_val'] == y_val_pred).double().mean().item()
print('Validation accuracy: %.2f%%' % val_acc)
# Out:
# Training accuracy: 9.24%
# Validation accuracy: 9.00%

# %% [markdown]
# Unfortunately, the performance of our initial model is quite bad. To find a better hyperparamters, we first modulized the functions that we've implemented as LinearSVM.

# %% [markdown]
# Now, please use the validation set to tune hyperparameters (regularization strength and learning rate). You should experiment with different ranges for the learning rates and regularization strengths.
#
# To get full credit for the assignment your best model found through cross-validation should achieve an accuracy of at least 37% on the validation set.
#
# (Our best model got over 38.1% -- did you beat us?)

# %%
import os
import eecs598
reload(linear_classifier)
from linear_classifier import LinearSVM, svm_get_search_params, test_one_param_set

# YOUR_TURN: find the best learning_rates and regularization_strengths combination
#            in 'svm_get_search_params'
learning_rates, regularization_strengths = svm_get_search_params()
num_models = len(learning_rates) * len(regularization_strengths)

####
# It is okay to comment out the following conditions when you are working on svm_get_search_params.
# But, please do not forget to reset back to the original setting once you are done.
if num_models > 25:
  raise Exception("Please do not test/submit more than 25 items at once")
elif num_models < 5:
  raise Exception("Please present at least 5 parameter sets in your final ipynb")
####


i = 0
# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (train_acc, val_acc).
results = {}
best_val = -1.0   # The highest validation accuracy that we have seen so far.
best_svm_model = None # The LinearSVM object that achieved the highest validation rate.
num_iters = 2000 # number of iterations

for lr in learning_rates:
  for reg in regularization_strengths:
    i += 1
    print('Training SVM %d / %d with learning_rate=%e and reg=%e'
          % (i, num_models, lr, reg))

    eecs598.reset_seed(0)
    # YOUR_TURN: implement a function that gives the trained model with
    #            train/validation accuracies in 'test_one_param_set'
    #            (note: this function will be used in Softmax Classifier section as well)
    cand_svm_model, cand_train_acc, cand_val_acc = test_one_param_set(LinearSVM(), data_dict, lr, reg, num_iters)

    if cand_val_acc > best_val:
      best_val = cand_val_acc
      best_svm_model = cand_svm_model # save the svm
    results[(lr, reg)] = (cand_train_acc, cand_val_acc)


# Print out results.
for lr, reg in sorted(results):
  train_acc, val_acc = results[(lr, reg)]
  print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
         lr, reg, train_acc, val_acc))

print('best validation accuracy achieved during cross-validation: %f' % best_val)

# save the best model
path = os.path.join(GOOGLE_DRIVE_PATH, 'svm_best_model.pt')
best_svm_model.save(path)
# Out:
# Training SVM 1 / 24 with learning_rate=1.000000e-04 and reg=1.000000e-01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 7.820028
# iteration 200 / 2000: loss 7.493730
# iteration 300 / 2000: loss 7.078526
# iteration 400 / 2000: loss 6.568957
# iteration 500 / 2000: loss 6.848626
# iteration 600 / 2000: loss 6.295605
# iteration 700 / 2000: loss 6.011152
# iteration 800 / 2000: loss 5.722735
# iteration 900 / 2000: loss 5.649502
# iteration 1000 / 2000: loss 5.737728
# iteration 1100 / 2000: loss 5.591261
# iteration 1200 / 2000: loss 5.936769
# iteration 1300 / 2000: loss 5.677937
# iteration 1400 / 2000: loss 5.947311
# iteration 1500 / 2000: loss 5.955789
# iteration 1600 / 2000: loss 5.736421
# iteration 1700 / 2000: loss 5.678564
# iteration 1800 / 2000: loss 5.909998
# iteration 1900 / 2000: loss 5.754898
# Training SVM 2 / 24 with learning_rate=1.000000e-04 and reg=1.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 7.828643
# iteration 200 / 2000: loss 7.507454
# iteration 300 / 2000: loss 7.100605
# iteration 400 / 2000: loss 6.602643
# iteration 500 / 2000: loss 6.879682
# iteration 600 / 2000: loss 6.348888
# iteration 700 / 2000: loss 6.061675
# iteration 800 / 2000: loss 5.795491
# iteration 900 / 2000: loss 5.723544
# iteration 1000 / 2000: loss 5.816872
# iteration 1100 / 2000: loss 5.685197
# iteration 1200 / 2000: loss 6.025776
# iteration 1300 / 2000: loss 5.773300
# iteration 1400 / 2000: loss 6.043317
# iteration 1500 / 2000: loss 6.064459
# iteration 1600 / 2000: loss 5.869407
# iteration 1700 / 2000: loss 5.790625
# iteration 1800 / 2000: loss 6.009776
# iteration 1900 / 2000: loss 5.862157
# Training SVM 3 / 24 with learning_rate=1.000000e-04 and reg=2.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 7.837936
# iteration 200 / 2000: loss 7.522767
# iteration 300 / 2000: loss 7.125353
# iteration 400 / 2000: loss 6.640243
# iteration 500 / 2000: loss 6.914470
# iteration 600 / 2000: loss 6.407555
# iteration 700 / 2000: loss 6.118883
# iteration 800 / 2000: loss 5.874163
# iteration 900 / 2000: loss 5.803306
# iteration 1000 / 2000: loss 5.905816
# iteration 1100 / 2000: loss 5.789882
# iteration 1200 / 2000: loss 6.119986
# iteration 1300 / 2000: loss 5.878785
# iteration 1400 / 2000: loss 6.152502
# iteration 1500 / 2000: loss 6.178678
# iteration 1600 / 2000: loss 6.015374
# iteration 1700 / 2000: loss 5.911540
# iteration 1800 / 2000: loss 6.116249
# iteration 1900 / 2000: loss 5.975308
# Training SVM 4 / 24 with learning_rate=1.000000e-04 and reg=1.000000e+01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 7.911692
# iteration 200 / 2000: loss 7.641016
# iteration 300 / 2000: loss 7.308757
# iteration 400 / 2000: loss 6.918890
# iteration 500 / 2000: loss 7.180086
# iteration 600 / 2000: loss 6.837955
# iteration 700 / 2000: loss 6.533667
# iteration 800 / 2000: loss 6.423016
# iteration 900 / 2000: loss 6.386317
# iteration 1000 / 2000: loss 6.501899
# iteration 1100 / 2000: loss 6.472536
# iteration 1200 / 2000: loss 6.716525
# iteration 1300 / 2000: loss 6.555895
# iteration 1400 / 2000: loss 6.805016
# iteration 1500 / 2000: loss 6.871982
# iteration 1600 / 2000: loss 6.832590
# iteration 1700 / 2000: loss 6.594043
# iteration 1800 / 2000: loss 6.683394
# iteration 1900 / 2000: loss 6.632538
# Training SVM 5 / 24 with learning_rate=1.000000e-03 and reg=1.000000e-01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.026923
# iteration 200 / 2000: loss 5.951548
# iteration 300 / 2000: loss 5.571258
# iteration 400 / 2000: loss 5.399923
# iteration 500 / 2000: loss 5.473144
# iteration 600 / 2000: loss 4.811814
# iteration 700 / 2000: loss 4.720678
# iteration 800 / 2000: loss 4.527985
# iteration 900 / 2000: loss 4.764505
# iteration 1000 / 2000: loss 4.524815
# iteration 1100 / 2000: loss 4.483180
# iteration 1200 / 2000: loss 4.849130
# iteration 1300 / 2000: loss 4.489140
# iteration 1400 / 2000: loss 4.711428
# iteration 1500 / 2000: loss 5.040332
# iteration 1600 / 2000: loss 4.450848
# iteration 1700 / 2000: loss 4.681424
# iteration 1800 / 2000: loss 4.907754
# iteration 1900 / 2000: loss 4.864472
# Training SVM 6 / 24 with learning_rate=1.000000e-03 and reg=1.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.102084
# iteration 200 / 2000: loss 6.099415
# iteration 300 / 2000: loss 5.740779
# iteration 400 / 2000: loss 5.580361
# iteration 500 / 2000: loss 5.758182
# iteration 600 / 2000: loss 5.208408
# iteration 700 / 2000: loss 5.098093
# iteration 800 / 2000: loss 4.906999
# iteration 900 / 2000: loss 5.058597
# iteration 1000 / 2000: loss 5.014199
# iteration 1100 / 2000: loss 4.940316
# iteration 1200 / 2000: loss 5.391099
# iteration 1300 / 2000: loss 5.072842
# iteration 1400 / 2000: loss 5.357821
# iteration 1500 / 2000: loss 5.505255
# iteration 1600 / 2000: loss 5.166514
# iteration 1700 / 2000: loss 5.292420
# iteration 1800 / 2000: loss 5.542871
# iteration 1900 / 2000: loss 5.437759
# Training SVM 7 / 24 with learning_rate=1.000000e-03 and reg=2.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.186042
# iteration 200 / 2000: loss 6.251628
# iteration 300 / 2000: loss 5.923347
# iteration 400 / 2000: loss 5.765417
# iteration 500 / 2000: loss 6.040455
# iteration 600 / 2000: loss 5.549788
# iteration 700 / 2000: loss 5.428114
# iteration 800 / 2000: loss 5.233536
# iteration 900 / 2000: loss 5.334697
# iteration 1000 / 2000: loss 5.380917
# iteration 1100 / 2000: loss 5.289470
# iteration 1200 / 2000: loss 5.743460
# iteration 1300 / 2000: loss 5.452024
# iteration 1400 / 2000: loss 5.749614
# iteration 1500 / 2000: loss 5.835966
# iteration 1600 / 2000: loss 5.606872
# iteration 1700 / 2000: loss 5.644864
# iteration 1800 / 2000: loss 5.880851
# iteration 1900 / 2000: loss 5.745390
# Training SVM 8 / 24 with learning_rate=1.000000e-03 and reg=1.000000e+01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.760212
# iteration 200 / 2000: loss 7.005963
# iteration 300 / 2000: loss 6.820963
# iteration 400 / 2000: loss 6.606902
# iteration 500 / 2000: loss 6.975581
# iteration 600 / 2000: loss 6.641877
# iteration 700 / 2000: loss 6.447666
# iteration 800 / 2000: loss 6.357129
# iteration 900 / 2000: loss 6.334653
# iteration 1000 / 2000: loss 6.442708
# iteration 1100 / 2000: loss 6.428972
# iteration 1200 / 2000: loss 6.722027
# iteration 1300 / 2000: loss 6.522878
# iteration 1400 / 2000: loss 6.778841
# iteration 1500 / 2000: loss 6.850414
# iteration 1600 / 2000: loss 6.830512
# iteration 1700 / 2000: loss 6.578099
# iteration 1800 / 2000: loss 6.699980
# iteration 1900 / 2000: loss 6.602815
# Training SVM 9 / 24 with learning_rate=2.000000e-03 and reg=1.000000e-01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.607833
# iteration 200 / 2000: loss 5.523118
# iteration 300 / 2000: loss 5.263690
# iteration 400 / 2000: loss 5.141488
# iteration 500 / 2000: loss 5.165480
# iteration 600 / 2000: loss 4.592494
# iteration 700 / 2000: loss 4.459378
# iteration 800 / 2000: loss 4.382830
# iteration 900 / 2000: loss 4.636806
# iteration 1000 / 2000: loss 4.368541
# iteration 1100 / 2000: loss 4.335740
# iteration 1200 / 2000: loss 4.702987
# iteration 1300 / 2000: loss 4.295391
# iteration 1400 / 2000: loss 4.524534
# iteration 1500 / 2000: loss 4.904591
# iteration 1600 / 2000: loss 4.298524
# iteration 1700 / 2000: loss 4.529358
# iteration 1800 / 2000: loss 4.720366
# iteration 1900 / 2000: loss 4.702219
# Training SVM 10 / 24 with learning_rate=2.000000e-03 and reg=1.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.744383
# iteration 200 / 2000: loss 5.796642
# iteration 300 / 2000: loss 5.566017
# iteration 400 / 2000: loss 5.459998
# iteration 500 / 2000: loss 5.660789
# iteration 600 / 2000: loss 5.147409
# iteration 700 / 2000: loss 5.032685
# iteration 800 / 2000: loss 4.913885
# iteration 900 / 2000: loss 5.039241
# iteration 1000 / 2000: loss 5.004979
# iteration 1100 / 2000: loss 4.940762
# iteration 1200 / 2000: loss 5.413899
# iteration 1300 / 2000: loss 5.065138
# iteration 1400 / 2000: loss 5.347215
# iteration 1500 / 2000: loss 5.490642
# iteration 1600 / 2000: loss 5.153574
# iteration 1700 / 2000: loss 5.288852
# iteration 1800 / 2000: loss 5.526258
# iteration 1900 / 2000: loss 5.424217
# Training SVM 11 / 24 with learning_rate=2.000000e-03 and reg=2.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.891124
# iteration 200 / 2000: loss 6.048750
# iteration 300 / 2000: loss 5.834061
# iteration 400 / 2000: loss 5.714751
# iteration 500 / 2000: loss 6.025907
# iteration 600 / 2000: loss 5.544506
# iteration 700 / 2000: loss 5.415007
# iteration 800 / 2000: loss 5.260909
# iteration 900 / 2000: loss 5.333469
# iteration 1000 / 2000: loss 5.391627
# iteration 1100 / 2000: loss 5.309418
# iteration 1200 / 2000: loss 5.775298
# iteration 1300 / 2000: loss 5.443872
# iteration 1400 / 2000: loss 5.742950
# iteration 1500 / 2000: loss 5.824497
# iteration 1600 / 2000: loss 5.608588
# iteration 1700 / 2000: loss 5.643235
# iteration 1800 / 2000: loss 5.862565
# iteration 1900 / 2000: loss 5.731500
# Training SVM 12 / 24 with learning_rate=2.000000e-03 and reg=1.000000e+01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.724523
# iteration 200 / 2000: loss 6.981814
# iteration 300 / 2000: loss 6.805707
# iteration 400 / 2000: loss 6.609584
# iteration 500 / 2000: loss 6.978265
# iteration 600 / 2000: loss 6.628592
# iteration 700 / 2000: loss 6.445791
# iteration 800 / 2000: loss 6.391936
# iteration 900 / 2000: loss 6.336858
# iteration 1000 / 2000: loss 6.457603
# iteration 1100 / 2000: loss 6.434474
# iteration 1200 / 2000: loss 6.731411
# iteration 1300 / 2000: loss 6.509142
# iteration 1400 / 2000: loss 6.773024
# iteration 1500 / 2000: loss 6.817775
# iteration 1600 / 2000: loss 6.832788
# iteration 1700 / 2000: loss 6.570513
# iteration 1800 / 2000: loss 6.700900
# iteration 1900 / 2000: loss 6.598580
# Training SVM 13 / 24 with learning_rate=5.000000e-03 and reg=1.000000e-01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.158606
# iteration 200 / 2000: loss 5.110000
# iteration 300 / 2000: loss 4.951218
# iteration 400 / 2000: loss 4.827975
# iteration 500 / 2000: loss 4.875815
# iteration 600 / 2000: loss 4.421653
# iteration 700 / 2000: loss 4.239865
# iteration 800 / 2000: loss 4.293388
# iteration 900 / 2000: loss 4.517763
# iteration 1000 / 2000: loss 4.275060
# iteration 1100 / 2000: loss 4.234623
# iteration 1200 / 2000: loss 4.652722
# iteration 1300 / 2000: loss 4.162219
# iteration 1400 / 2000: loss 4.417435
# iteration 1500 / 2000: loss 4.764374
# iteration 1600 / 2000: loss 4.187158
# iteration 1700 / 2000: loss 4.430217
# iteration 1800 / 2000: loss 4.585609
# iteration 1900 / 2000: loss 4.617873
# Training SVM 14 / 24 with learning_rate=5.000000e-03 and reg=1.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.433441
# iteration 200 / 2000: loss 5.590096
# iteration 300 / 2000: loss 5.492437
# iteration 400 / 2000: loss 5.410892
# iteration 500 / 2000: loss 5.668718
# iteration 600 / 2000: loss 5.141493
# iteration 700 / 2000: loss 5.011602
# iteration 800 / 2000: loss 4.966208
# iteration 900 / 2000: loss 5.040060
# iteration 1000 / 2000: loss 5.061465
# iteration 1100 / 2000: loss 4.975751
# iteration 1200 / 2000: loss 5.498053
# iteration 1300 / 2000: loss 5.065875
# iteration 1400 / 2000: loss 5.348808
# iteration 1500 / 2000: loss 5.459247
# iteration 1600 / 2000: loss 5.151327
# iteration 1700 / 2000: loss 5.276338
# iteration 1800 / 2000: loss 5.492104
# iteration 1900 / 2000: loss 5.410639
# Training SVM 15 / 24 with learning_rate=5.000000e-03 and reg=2.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.711543
# iteration 200 / 2000: loss 5.953195
# iteration 300 / 2000: loss 5.818100
# iteration 400 / 2000: loss 5.706671
# iteration 500 / 2000: loss 6.066418
# iteration 600 / 2000: loss 5.549844
# iteration 700 / 2000: loss 5.400984
# iteration 800 / 2000: loss 5.308293
# iteration 900 / 2000: loss 5.341099
# iteration 1000 / 2000: loss 5.456468
# iteration 1100 / 2000: loss 5.348728
# iteration 1200 / 2000: loss 5.844495
# iteration 1300 / 2000: loss 5.424735
# iteration 1400 / 2000: loss 5.742432
# iteration 1500 / 2000: loss 5.779167
# iteration 1600 / 2000: loss 5.611037
# iteration 1700 / 2000: loss 5.627083
# iteration 1800 / 2000: loss 5.827964
# iteration 1900 / 2000: loss 5.719079
# Training SVM 16 / 24 with learning_rate=5.000000e-03 and reg=1.000000e+01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.759453
# iteration 200 / 2000: loss 6.969831
# iteration 300 / 2000: loss 6.769950
# iteration 400 / 2000: loss 6.606052
# iteration 500 / 2000: loss 6.972350
# iteration 600 / 2000: loss 6.610251
# iteration 700 / 2000: loss 6.445794
# iteration 800 / 2000: loss 6.463738
# iteration 900 / 2000: loss 6.358191
# iteration 1000 / 2000: loss 6.498773
# iteration 1100 / 2000: loss 6.473612
# iteration 1200 / 2000: loss 6.751578
# iteration 1300 / 2000: loss 6.523834
# iteration 1400 / 2000: loss 6.761415
# iteration 1500 / 2000: loss 6.744059
# iteration 1600 / 2000: loss 6.850433
# iteration 1700 / 2000: loss 6.563585
# iteration 1800 / 2000: loss 6.688080
# iteration 1900 / 2000: loss 6.602808
# Training SVM 17 / 24 with learning_rate=1.000000e-02 and reg=1.000000e-01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 4.928797
# iteration 200 / 2000: loss 4.938688
# iteration 300 / 2000: loss 4.793853
# iteration 400 / 2000: loss 4.691817
# iteration 500 / 2000: loss 4.782645
# iteration 600 / 2000: loss 4.329942
# iteration 700 / 2000: loss 4.170357
# iteration 800 / 2000: loss 4.253232
# iteration 900 / 2000: loss 4.468750
# iteration 1000 / 2000: loss 4.321505
# iteration 1100 / 2000: loss 4.205594
# iteration 1200 / 2000: loss 4.703693
# iteration 1300 / 2000: loss 4.181305
# iteration 1400 / 2000: loss 4.420988
# iteration 1500 / 2000: loss 4.691836
# iteration 1600 / 2000: loss 4.153771
# iteration 1700 / 2000: loss 4.415133
# iteration 1800 / 2000: loss 4.524328
# iteration 1900 / 2000: loss 4.617156
# Training SVM 18 / 24 with learning_rate=1.000000e-02 and reg=1.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.374947
# iteration 200 / 2000: loss 5.597102
# iteration 300 / 2000: loss 5.498684
# iteration 400 / 2000: loss 5.418071
# iteration 500 / 2000: loss 5.735910
# iteration 600 / 2000: loss 5.141784
# iteration 700 / 2000: loss 5.013918
# iteration 800 / 2000: loss 5.004365
# iteration 900 / 2000: loss 5.053143
# iteration 1000 / 2000: loss 5.166763
# iteration 1100 / 2000: loss 5.007971
# iteration 1200 / 2000: loss 5.572002
# iteration 1300 / 2000: loss 5.081043
# iteration 1400 / 2000: loss 5.371690
# iteration 1500 / 2000: loss 5.437685
# iteration 1600 / 2000: loss 5.155674
# iteration 1700 / 2000: loss 5.294965
# iteration 1800 / 2000: loss 5.442365
# iteration 1900 / 2000: loss 5.391882
# Training SVM 19 / 24 with learning_rate=1.000000e-02 and reg=2.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.729911
# iteration 200 / 2000: loss 5.977362
# iteration 300 / 2000: loss 5.821658
# iteration 400 / 2000: loss 5.735588
# iteration 500 / 2000: loss 6.100126
# iteration 600 / 2000: loss 5.541422
# iteration 700 / 2000: loss 5.403669
# iteration 800 / 2000: loss 5.368478
# iteration 900 / 2000: loss 5.361114
# iteration 1000 / 2000: loss 5.562098
# iteration 1100 / 2000: loss 5.387641
# iteration 1200 / 2000: loss 5.894438
# iteration 1300 / 2000: loss 5.457193
# iteration 1400 / 2000: loss 5.754140
# iteration 1500 / 2000: loss 5.739630
# iteration 1600 / 2000: loss 5.605637
# iteration 1700 / 2000: loss 5.648798
# iteration 1800 / 2000: loss 5.802248
# iteration 1900 / 2000: loss 5.714913
# Training SVM 20 / 24 with learning_rate=1.000000e-02 and reg=1.000000e+01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.793566
# iteration 200 / 2000: loss 6.987445
# iteration 300 / 2000: loss 6.737836
# iteration 400 / 2000: loss 6.625786
# iteration 500 / 2000: loss 6.993289
# iteration 600 / 2000: loss 6.645872
# iteration 700 / 2000: loss 6.454142
# iteration 800 / 2000: loss 6.508425
# iteration 900 / 2000: loss 6.435024
# iteration 1000 / 2000: loss 6.606397
# iteration 1100 / 2000: loss 6.518910
# iteration 1200 / 2000: loss 6.808731
# iteration 1300 / 2000: loss 6.572043
# iteration 1400 / 2000: loss 6.765334
# iteration 1500 / 2000: loss 6.696539
# iteration 1600 / 2000: loss 6.912464
# iteration 1700 / 2000: loss 6.577222
# iteration 1800 / 2000: loss 6.674001
# iteration 1900 / 2000: loss 6.641125
# Training SVM 21 / 24 with learning_rate=2.000000e-02 and reg=1.000000e-01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 4.806455
# iteration 200 / 2000: loss 4.915749
# iteration 300 / 2000: loss 4.748072
# iteration 400 / 2000: loss 4.663255
# iteration 500 / 2000: loss 4.742297
# iteration 600 / 2000: loss 4.313347
# iteration 700 / 2000: loss 4.194138
# iteration 800 / 2000: loss 4.267032
# iteration 900 / 2000: loss 4.464708
# iteration 1000 / 2000: loss 4.513185
# iteration 1100 / 2000: loss 4.207200
# iteration 1200 / 2000: loss 4.842071
# iteration 1300 / 2000: loss 4.283351
# iteration 1400 / 2000: loss 4.477903
# iteration 1500 / 2000: loss 4.684420
# iteration 1600 / 2000: loss 4.201723
# iteration 1700 / 2000: loss 4.484383
# iteration 1800 / 2000: loss 4.461968
# iteration 1900 / 2000: loss 4.588128
# Training SVM 22 / 24 with learning_rate=2.000000e-02 and reg=1.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.438572
# iteration 200 / 2000: loss 5.705378
# iteration 300 / 2000: loss 5.539443
# iteration 400 / 2000: loss 5.492758
# iteration 500 / 2000: loss 5.756243
# iteration 600 / 2000: loss 5.188376
# iteration 700 / 2000: loss 5.103757
# iteration 800 / 2000: loss 5.128453
# iteration 900 / 2000: loss 5.098695
# iteration 1000 / 2000: loss 5.426006
# iteration 1100 / 2000: loss 5.110340
# iteration 1200 / 2000: loss 5.743802
# iteration 1300 / 2000: loss 5.136842
# iteration 1400 / 2000: loss 5.453303
# iteration 1500 / 2000: loss 5.426004
# iteration 1600 / 2000: loss 5.253175
# iteration 1700 / 2000: loss 5.377094
# iteration 1800 / 2000: loss 5.421412
# iteration 1900 / 2000: loss 5.386695
# Training SVM 23 / 24 with learning_rate=2.000000e-02 and reg=2.000000e+00
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 5.810987
# iteration 200 / 2000: loss 6.090241
# iteration 300 / 2000: loss 5.833645
# iteration 400 / 2000: loss 5.828548
# iteration 500 / 2000: loss 6.164721
# iteration 600 / 2000: loss 5.616250
# iteration 700 / 2000: loss 5.498355
# iteration 800 / 2000: loss 5.519347
# iteration 900 / 2000: loss 5.444751
# iteration 1000 / 2000: loss 5.832435
# iteration 1100 / 2000: loss 5.499241
# iteration 1200 / 2000: loss 6.068591
# iteration 1300 / 2000: loss 5.542992
# iteration 1400 / 2000: loss 5.851383
# iteration 1500 / 2000: loss 5.747019
# iteration 1600 / 2000: loss 5.738734
# iteration 1700 / 2000: loss 5.703602
# iteration 1800 / 2000: loss 5.778000
# iteration 1900 / 2000: loss 5.748066
# Training SVM 24 / 24 with learning_rate=2.000000e-02 and reg=1.000000e+01
# iteration 0 / 2000: loss 9.000016
# iteration 100 / 2000: loss 6.838330
# iteration 200 / 2000: loss 7.133320
# iteration 300 / 2000: loss 6.708677
# iteration 400 / 2000: loss 6.698911
# iteration 500 / 2000: loss 7.138190
# iteration 600 / 2000: loss 6.865391
# iteration 700 / 2000: loss 6.532002
# iteration 800 / 2000: loss 6.578698
# iteration 900 / 2000: loss 6.651475
# iteration 1000 / 2000: loss 6.975674
# iteration 1100 / 2000: loss 6.517282
# iteration 1200 / 2000: loss 7.008761
# iteration 1300 / 2000: loss 6.644306
# iteration 1400 / 2000: loss 6.822606
# iteration 1500 / 2000: loss 6.648353
# iteration 1600 / 2000: loss 7.035910
# iteration 1700 / 2000: loss 6.601982
# iteration 1800 / 2000: loss 6.630217
# iteration 1900 / 2000: loss 6.821812
# lr 1.000000e-04 reg 1.000000e-01 train accuracy: 0.337450 val accuracy: 0.329900
# lr 1.000000e-04 reg 1.000000e+00 train accuracy: 0.332900 val accuracy: 0.324500
# lr 1.000000e-04 reg 2.000000e+00 train accuracy: 0.327500 val accuracy: 0.321400
# lr 1.000000e-04 reg 1.000000e+01 train accuracy: 0.292900 val accuracy: 0.292200
# lr 1.000000e-03 reg 1.000000e-01 train accuracy: 0.386875 val accuracy: 0.373500
# lr 1.000000e-03 reg 1.000000e+00 train accuracy: 0.360500 val accuracy: 0.352100
# lr 1.000000e-03 reg 2.000000e+00 train accuracy: 0.342025 val accuracy: 0.338100
# lr 1.000000e-03 reg 1.000000e+01 train accuracy: 0.290675 val accuracy: 0.287700
# lr 2.000000e-03 reg 1.000000e-01 train accuracy: 0.394025 val accuracy: 0.380000
# lr 2.000000e-03 reg 1.000000e+00 train accuracy: 0.360475 val accuracy: 0.350300
# lr 2.000000e-03 reg 2.000000e+00 train accuracy: 0.340500 val accuracy: 0.337300
# lr 2.000000e-03 reg 1.000000e+01 train accuracy: 0.289350 val accuracy: 0.288700
# lr 5.000000e-03 reg 1.000000e-01 train accuracy: 0.397300 val accuracy: 0.383300
# lr 5.000000e-03 reg 1.000000e+00 train accuracy: 0.354425 val accuracy: 0.346000
# lr 5.000000e-03 reg 2.000000e+00 train accuracy: 0.338825 val accuracy: 0.335900
# lr 5.000000e-03 reg 1.000000e+01 train accuracy: 0.290575 val accuracy: 0.288900
# lr 1.000000e-02 reg 1.000000e-01 train accuracy: 0.392425 val accuracy: 0.380800
# lr 1.000000e-02 reg 1.000000e+00 train accuracy: 0.346825 val accuracy: 0.342700
# lr 1.000000e-02 reg 2.000000e+00 train accuracy: 0.333300 val accuracy: 0.332300
# lr 1.000000e-02 reg 1.000000e+01 train accuracy: 0.290625 val accuracy: 0.287800
# lr 2.000000e-02 reg 1.000000e-01 train accuracy: 0.379200 val accuracy: 0.364700
# lr 2.000000e-02 reg 1.000000e+00 train accuracy: 0.330475 val accuracy: 0.331000
# lr 2.000000e-02 reg 2.000000e+00 train accuracy: 0.314850 val accuracy: 0.314400
# lr 2.000000e-02 reg 1.000000e+01 train accuracy: 0.259675 val accuracy: 0.258800
# best validation accuracy achieved during cross-validation: 0.383300
# Saved in drive/My Drive/A2/svm_best_model.pt

# %% [markdown]
# Visualize the cross-validation results. You can use this as a debugging tool -- after examining the cross-validation results here, you may want to go back and rerun your cross-validation from above.

# %%
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')
plt.gcf().set_size_inches(8, 5)
plt.show()

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.gcf().set_size_inches(8, 5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1982741659.py in <cell line: 0>()
#       5 marker_size = 100
#       6 colors = [results[x][0] for x in results]
# ----> 7 plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
#       8 plt.colorbar()
#       9 plt.xlabel('log learning rate')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# -> 3939     __ret = gca().scatter(
#    3940         x,
#    3941         y,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4916             orig_edgecolor = kwargs.get('edgecolor', None)
#    4917         c, colors, edgecolors = \
# -> 4918             self._parse_scatter_color_args(
#    4919                 c, edgecolors, kwargs, x.size,
#    4920                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4695         if not c_was_none and kwcolor is None and not c_is_string_or_strings:
#    4696             try:  # First, does 'c' look suitable for value-mapping?
# -> 4697                 c = np.asanyarray(c, dtype=float)
#    4698             except ValueError:
#    4699                 pass  # Failed to convert to float array; must be color specs.
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in __array__(self, dtype)
#    1211             return self.numpy()
#    1212         else:
# -> 1213             return self.numpy().astype(dtype, copy=False)
#    1214
#    1215     # Wrap Numpy array again in a suitable tensor when done, to support e.g.
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %% [markdown]
# Evaluate the best svm on test set. To get full credit for the assignment you should achieve a test-set accuracy above 35%.
#
# (Our best was over 39.1% -- did you beat us?)

# %%
import eecs598

eecs598.reset_seed(0)
y_test_pred = best_svm_model.predict(data_dict['X_test'])
test_accuracy = torch.mean((data_dict['y_test'] == y_test_pred).double())
print('linear SVM on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# linear SVM on raw pixels final test set accuracy: 0.389000

# %% [markdown]
# Visualize the learned weights for each class. Depending on your choice of learning rate and regularization strength, these may or may not be nice to look at.

# %%
w = best_svm_model.W[:-1,:] # strip out the bias
w = w.reshape(3, 32, 32, 10)
w = w.transpose(0, 2).transpose(1, 0)

w_min, w_max = torch.min(w), torch.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
  plt.subplot(2, 5, i + 1)

  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.type(torch.uint8).cpu())
  plt.axis('off')
  plt.title(classes[i])

# %% [markdown]
# # Softmax Classifier
#
# Similar to the SVM, you will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights
#
# As noted in the SVM section, you SHOULD NOT use ".to()" or ".cuda()" in each implementation block.

# %% [markdown]
# First, let's start from implementing the naive softmax loss function with nested loops in `softmax_loss_naive` function.

# %% [markdown]
# As a sanity check to see whether we have implemented the loss correctly, run the softmax classifier with a small random weight matrix and no regularization. You should see loss near log(10) = 2.3

# %%
import eecs598
from importlib import reload
import linear_classifier
reload(linear_classifier)
from linear_classifier import softmax_loss_naive

eecs598.reset_seed(0)
# Generate a random softmax weight tensor and use it to compute the loss.
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)

X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]

# YOUR_TURN: Complete the implementation of softmax_loss_naive and implement
# a (naive) version of the gradient that uses nested loops.
loss, _ = softmax_loss_naive(W, X_batch, y_batch, reg=0.0)

# As a rough sanity check, our loss should be something close to log(10.0).
print('loss: %f' % loss)
print('sanity check: %f' % (math.log(10.0)))
# Out:
# loss: 2.302826
# sanity check: 2.302585

# %% [markdown]
# Next, we use gradient checking to debug the analytic gradient of our naive softmax loss function. If you've implemented the gradient correctly, you should see relative errors less than `1e-5`.

# %%
import eecs598
reload(linear_classifier)
from linear_classifier import softmax_loss_naive

eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)

X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]

# YOUR_TURN: Complete the implementation of softmax_loss_naive and implement
# a (naive) version of the gradient that uses nested loops.
_, grad = softmax_loss_naive(W, X_batch, y_batch, reg=0.0)

f = lambda w: softmax_loss_naive(w, X_batch, y_batch, reg=0.0)[0]
eecs598.grad.grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.000000 analytic: 0.003046, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.006308, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.005392, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.002581, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.007512, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.006417, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.011391, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.001822, relative error: 1.000000e+00
# numerical: 0.000000 analytic: -0.014710, relative error: 1.000000e+00
# numerical: 0.000000 analytic: -0.005153, relative error: 1.000000e+00

# %% [markdown]
# Let's perform another gradient check with regularization enabled. Again you should see relative errors less than `1e-5`.

# %%
import eecs598
from linear_classifier import softmax_loss_naive

eecs598.reset_seed(128)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
reg = 10.0

X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]

# YOUR_TURN: Complete the gradient compuation part of softmax_loss_naive
_, grad = softmax_loss_naive(W, X_batch, y_batch, reg)

f = lambda w: softmax_loss_naive(w, X_batch, y_batch, reg)[0]
eecs598.grad.grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.000000 analytic: 0.003050, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.006294, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.005340, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.002568, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.007492, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.006410, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.011371, relative error: 1.000000e+00
# numerical: 0.000000 analytic: 0.001810, relative error: 1.000000e+00
# numerical: 0.000000 analytic: -0.014676, relative error: 1.000000e+00
# numerical: 0.000000 analytic: -0.005167, relative error: 1.000000e+00

# %% [markdown]
# Then, let's move on to the vectorized form: `softmax_loss_vectorized`.

# %% [markdown]
# Now that we have a naive implementation of the softmax loss function and its gradient, implement a vectorized version in softmax_loss_vectorized. The two versions should compute the same results, but the vectorized version should be much faster.
#
# The differences between the naive and vectorized losses and gradients should both be less than `1e-6`, and your vectorized implementation should be at least 20x faster than the naive implementation.

# %%
import eecs598
reload(linear_classifier)
from linear_classifier import softmax_loss_naive, softmax_loss_vectorized

eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
reg = 0.05

X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]

# Run and time the naive version
torch.cuda.synchronize()
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_naive = 1000.0 * (toc - tic)
print('naive loss: %e computed in %fs' % (loss_naive, ms_naive))

# Run and time the vectorized version
# YOUR_TURN: Complete the implementation of softmax_loss_vectorized
torch.cuda.synchronize()
tic = time.time()
loss_vec, grad_vec = softmax_loss_vectorized(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_vec = 1000.0 * (toc - tic)
print('vectorized loss: %e computed in %fs' % (loss_vec, ms_vec))

# we use the Frobenius norm to compare the two versions of the gradient.
loss_diff = (loss_naive - loss_vec).abs().item()
grad_diff = torch.norm(grad_naive - grad_vec, p='fro')
print('Loss difference: %.2e' % loss_diff)
print('Gradient difference: %.2e' % grad_diff)
print('Speedup: %.2fX' % (ms_naive / ms_vec))
# Out:
# naive loss: 2.302826e+00 computed in 108.145237s
# vectorized loss: 2.302841e+00 computed in 2.425194s
# Loss difference: 1.54e-05
# Gradient difference: 6.82e-16
# Speedup: 44.59X

# %% [markdown]
# Let's check that your implementation of the softmax loss is numerically stable.
#
# If either of the following print `nan` then you should double-check the numeric stability of your implementations.

# %%
import eecs598
reload(linear_classifier)
from linear_classifier import train_linear_classifier, softmax_loss_naive, softmax_loss_vectorized

eecs598.reset_seed(0)
device = data_dict['X_train'].device
dtype = data_dict['X_train'].dtype
D = data_dict['X_train'].shape[1]
C = 10

# YOUR_TURN??: train_linear_classifier should be same as what you've implemented in the SVM section
W_ones = torch.ones(D, C, device=device, dtype=dtype)
W, loss_hist = train_linear_classifier(softmax_loss_naive, W_ones,
                                       data_dict['X_train'],
                                       data_dict['y_train'],
                                       learning_rate=1e-8, reg=2.5e4,
                                       num_iters=1, verbose=True)


W_ones = torch.ones(D, C, device=device, dtype=dtype)
W, loss_hist = train_linear_classifier(softmax_loss_vectorized, W_ones,
                                       data_dict['X_train'],
                                       data_dict['y_train'],
                                       learning_rate=1e-8, reg=2.5e4,
                                       num_iters=1, verbose=True)
# Out:
# iteration 0 / 1: loss nan
# iteration 0 / 1: loss 768250002.302585

# %% [markdown]
# Now lets train a softmax classifier with some default hyperparameters:

# %%
import eecs598
from linear_classifier import softmax_loss_vectorized

eecs598.reset_seed(0)

torch.cuda.synchronize()
tic = time.time()

# YOUR_TURN??: train_linear_classifier should be same as what you've implemented in the SVM section
W, loss_hist = train_linear_classifier(softmax_loss_vectorized, None,
                                       data_dict['X_train'],
                                       data_dict['y_train'],
                                       learning_rate=1e-10, reg=2.5e4,
                                       num_iters=1500, verbose=True)

torch.cuda.synchronize()
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 2.303356
# iteration 100 / 1500: loss 2.303354
# iteration 200 / 1500: loss 2.303355
# iteration 300 / 1500: loss 2.303354
# iteration 400 / 1500: loss 2.303355
# iteration 500 / 1500: loss 2.303355
# iteration 600 / 1500: loss 2.303355
# iteration 700 / 1500: loss 2.303355
# iteration 800 / 1500: loss 2.303355
# iteration 900 / 1500: loss 2.303355
# iteration 1000 / 1500: loss 2.303355
# iteration 1100 / 1500: loss 2.303357
# iteration 1200 / 1500: loss 2.303357
# iteration 1300 / 1500: loss 2.303355
# iteration 1400 / 1500: loss 2.303356
# That took 2.361827s

# %% [markdown]
# Plot the loss curve:

# %%
plt.plot(loss_hist, 'o')
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# Let's compute the accuracy of current model. It should be less than 10%.

# %%
import eecs598
from linear_classifier import predict_linear_classifier

eecs598.reset_seed(0)

# evaluate the performance on both the training and validation set
# YOUR_TURN??: predict_linear_classifier should be same as what you've implemented before, in the SVM section
y_train_pred = predict_linear_classifier(W, data_dict['X_train'])
train_acc = 100.0 * (data_dict['y_train'] == y_train_pred).double().mean().item()
print('training accuracy: %.2f%%' % train_acc)
y_val_pred = predict_linear_classifier(W, data_dict['X_val'])
val_acc = 100.0 * (data_dict['y_val'] == y_val_pred).double().mean().item()
print('validation accuracy: %.2f%%' % val_acc)
# Out:
# training accuracy: 8.90%
# validation accuracy: 8.54%

# %% [markdown]
# Now use the validation set to tune hyperparameters (regularization strength and learning rate). You should experiment with different ranges for the learning rates and regularization strengths.
#
# To get full credit for the assignment, your best model found through cross-validation should achieve an accuracy above 0.37 on the validation set.
#
# (Our best model was above 39.8% -- did you beat us?)

# %%
import os
import eecs598
reload(linear_classifier)
from linear_classifier import Softmax, softmax_get_search_params, test_one_param_set

# YOUR_TURN: find the best learning_rates and regularization_strengths combination
#            in 'softmax_get_search_params'
learning_rates, regularization_strengths = softmax_get_search_params()
num_models = len(learning_rates) * len(regularization_strengths)

####
# It is okay to comment out the following conditions when you are working on svm_get_search_params.
# But, please do not forget to reset back to the original setting once you are done.
if num_models > 25:
  raise Exception("Please do not test/submit more than 25 items at once")
elif num_models < 5:
  raise Exception("Please present at least 5 parameter sets in your final ipynb")
####


i = 0
# As before, store your cross-validation results in this dictionary.
# The keys should be tuples of (learning_rate, regularization_strength) and
# the values should be tuples (train_acc, val_acc)
results = {}
best_val = -1.0   # The highest validation accuracy that we have seen so far.
best_softmax_model = None # The Softmax object that achieved the highest validation rate.
num_iters = 2000 # number of iterations

for lr in learning_rates:
  for reg in regularization_strengths:
    i += 1
    print('Training Softmax %d / %d with learning_rate=%e and reg=%e'
          % (i, num_models, lr, reg))

    eecs598.reset_seed(0)
    cand_softmax_model, cand_train_acc, cand_val_acc = test_one_param_set(Softmax(), data_dict, lr, reg, num_iters)

    if cand_val_acc > best_val:
      best_val = cand_val_acc
      best_softmax_model = cand_softmax_model # save the classifier
    results[(lr, reg)] = (cand_train_acc, cand_val_acc)


# Print out results.
for lr, reg in sorted(results):
  train_acc, val_acc = results[(lr, reg)]
  print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
         lr, reg, train_acc, val_acc))

print('best validation accuracy achieved during cross-validation: %f' % best_val)

# save the best model
path = os.path.join(GOOGLE_DRIVE_PATH, 'softmax_best_model.pt')
best_softmax_model.save(path)
# Out:
# Training Softmax 1 / 24 with learning_rate=1.000000e-04 and reg=1.000000e-01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.290757
# iteration 200 / 2000: loss 2.283595
# iteration 300 / 2000: loss 2.271154
# iteration 400 / 2000: loss 2.255292
# iteration 500 / 2000: loss 2.258360
# iteration 600 / 2000: loss 2.246232
# iteration 700 / 2000: loss 2.220495
# iteration 800 / 2000: loss 2.211092
# iteration 900 / 2000: loss 2.199586
# iteration 1000 / 2000: loss 2.201622
# iteration 1100 / 2000: loss 2.196779
# iteration 1200 / 2000: loss 2.193266
# iteration 1300 / 2000: loss 2.182702
# iteration 1400 / 2000: loss 2.195512
# iteration 1500 / 2000: loss 2.195182
# iteration 1600 / 2000: loss 2.200350
# iteration 1700 / 2000: loss 2.163453
# iteration 1800 / 2000: loss 2.159426
# iteration 1900 / 2000: loss 2.159221
# Training Softmax 2 / 24 with learning_rate=1.000000e-04 and reg=1.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.290873
# iteration 200 / 2000: loss 2.284033
# iteration 300 / 2000: loss 2.272103
# iteration 400 / 2000: loss 2.256929
# iteration 500 / 2000: loss 2.260830
# iteration 600 / 2000: loss 2.249679
# iteration 700 / 2000: loss 2.225054
# iteration 800 / 2000: loss 2.216852
# iteration 900 / 2000: loss 2.206670
# iteration 1000 / 2000: loss 2.210077
# iteration 1100 / 2000: loss 2.206704
# iteration 1200 / 2000: loss 2.204744
# iteration 1300 / 2000: loss 2.195748
# iteration 1400 / 2000: loss 2.210209
# iteration 1500 / 2000: loss 2.211591
# iteration 1600 / 2000: loss 2.218480
# iteration 1700 / 2000: loss 2.183432
# iteration 1800 / 2000: loss 2.181256
# iteration 1900 / 2000: loss 2.182921
# Training Softmax 3 / 24 with learning_rate=1.000000e-04 and reg=2.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.291001
# iteration 200 / 2000: loss 2.284520
# iteration 300 / 2000: loss 2.273156
# iteration 400 / 2000: loss 2.258748
# iteration 500 / 2000: loss 2.263571
# iteration 600 / 2000: loss 2.253504
# iteration 700 / 2000: loss 2.230113
# iteration 800 / 2000: loss 2.223243
# iteration 900 / 2000: loss 2.214529
# iteration 1000 / 2000: loss 2.219454
# iteration 1100 / 2000: loss 2.217711
# iteration 1200 / 2000: loss 2.217471
# iteration 1300 / 2000: loss 2.210210
# iteration 1400 / 2000: loss 2.226499
# iteration 1500 / 2000: loss 2.229776
# iteration 1600 / 2000: loss 2.238568
# iteration 1700 / 2000: loss 2.205565
# iteration 1800 / 2000: loss 2.205436
# iteration 1900 / 2000: loss 2.209168
# Training Softmax 4 / 24 with learning_rate=1.000000e-04 and reg=1.000000e+01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.292028
# iteration 200 / 2000: loss 2.288405
# iteration 300 / 2000: loss 2.281558
# iteration 400 / 2000: loss 2.273245
# iteration 500 / 2000: loss 2.285407
# iteration 600 / 2000: loss 2.283949
# iteration 700 / 2000: loss 2.270342
# iteration 800 / 2000: loss 2.274019
# iteration 900 / 2000: loss 2.276920
# iteration 1000 / 2000: loss 2.293839
# iteration 1100 / 2000: loss 2.304950
# iteration 1200 / 2000: loss 2.318267
# iteration 1300 / 2000: loss 2.324653
# iteration 1400 / 2000: loss 2.355310
# iteration 1500 / 2000: loss 2.373459
# iteration 1600 / 2000: loss 2.397159
# iteration 1700 / 2000: loss 2.380178
# iteration 1800 / 2000: loss 2.396048
# iteration 1900 / 2000: loss 2.415921
# Training Softmax 5 / 24 with learning_rate=1.000000e-03 and reg=1.000000e-01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.215363
# iteration 200 / 2000: loss 2.188537
# iteration 300 / 2000: loss 2.146358
# iteration 400 / 2000: loss 2.098302
# iteration 500 / 2000: loss 2.135726
# iteration 600 / 2000: loss 2.079644
# iteration 700 / 2000: loss 2.018630
# iteration 800 / 2000: loss 1.998581
# iteration 900 / 2000: loss 1.991273
# iteration 1000 / 2000: loss 2.018443
# iteration 1100 / 2000: loss 1.999644
# iteration 1200 / 2000: loss 2.024603
# iteration 1300 / 2000: loss 1.986840
# iteration 1400 / 2000: loss 2.031653
# iteration 1500 / 2000: loss 2.037249
# iteration 1600 / 2000: loss 2.020810
# iteration 1700 / 2000: loss 2.016672
# iteration 1800 / 2000: loss 2.032638
# iteration 1900 / 2000: loss 1.994548
# Training Softmax 6 / 24 with learning_rate=1.000000e-03 and reg=1.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.223928
# iteration 200 / 2000: loss 2.214101
# iteration 300 / 2000: loss 2.192181
# iteration 400 / 2000: loss 2.166334
# iteration 500 / 2000: loss 2.226165
# iteration 600 / 2000: loss 2.193835
# iteration 700 / 2000: loss 2.157238
# iteration 800 / 2000: loss 2.161549
# iteration 900 / 2000: loss 2.179205
# iteration 1000 / 2000: loss 2.230298
# iteration 1100 / 2000: loss 2.236386
# iteration 1200 / 2000: loss 2.286207
# iteration 1300 / 2000: loss 2.272494
# iteration 1400 / 2000: loss 2.342034
# iteration 1500 / 2000: loss 2.372955
# iteration 1600 / 2000: loss 2.380563
# iteration 1700 / 2000: loss 2.401396
# iteration 1800 / 2000: loss 2.441857
# iteration 1900 / 2000: loss 2.428851
# Training Softmax 7 / 24 with learning_rate=1.000000e-03 and reg=2.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.233428
# iteration 200 / 2000: loss 2.242409
# iteration 300 / 2000: loss 2.242843
# iteration 400 / 2000: loss 2.241434
# iteration 500 / 2000: loss 2.325850
# iteration 600 / 2000: loss 2.319513
# iteration 700 / 2000: loss 2.309564
# iteration 800 / 2000: loss 2.340373
# iteration 900 / 2000: loss 2.385120
# iteration 1000 / 2000: loss 2.462069
# iteration 1100 / 2000: loss 2.495000
# iteration 1200 / 2000: loss 2.571554
# iteration 1300 / 2000: loss 2.583598
# iteration 1400 / 2000: loss 2.679568
# iteration 1500 / 2000: loss 2.737495
# iteration 1600 / 2000: loss 2.770631
# iteration 1700 / 2000: loss 2.817938
# iteration 1800 / 2000: loss 2.884268
# iteration 1900 / 2000: loss 2.897700
# Training Softmax 8 / 24 with learning_rate=1.000000e-03 and reg=1.000000e+01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.308793
# iteration 200 / 2000: loss 2.465225
# iteration 300 / 2000: loss 2.638691
# iteration 400 / 2000: loss 2.824054
# iteration 500 / 2000: loss 3.093656
# iteration 600 / 2000: loss 3.280823
# iteration 700 / 2000: loss 3.466614
# iteration 800 / 2000: loss 3.689148
# iteration 900 / 2000: loss 3.927606
# iteration 1000 / 2000: loss 4.185833
# iteration 1100 / 2000: loss 4.405278
# iteration 1200 / 2000: loss 4.664811
# iteration 1300 / 2000: loss 4.849663
# iteration 1400 / 2000: loss 5.121396
# iteration 1500 / 2000: loss 5.357012
# iteration 1600 / 2000: loss 5.554369
# iteration 1700 / 2000: loss 5.771004
# iteration 1800 / 2000: loss 5.999692
# iteration 1900 / 2000: loss 6.177451
# Training Softmax 9 / 24 with learning_rate=2.000000e-03 and reg=1.000000e-01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.168404
# iteration 200 / 2000: loss 2.142647
# iteration 300 / 2000: loss 2.096070
# iteration 400 / 2000: loss 2.049769
# iteration 500 / 2000: loss 2.094066
# iteration 600 / 2000: loss 2.018719
# iteration 700 / 2000: loss 1.968200
# iteration 800 / 2000: loss 1.939827
# iteration 900 / 2000: loss 1.943665
# iteration 1000 / 2000: loss 1.975283
# iteration 1100 / 2000: loss 1.954777
# iteration 1200 / 2000: loss 1.997039
# iteration 1300 / 2000: loss 1.945306
# iteration 1400 / 2000: loss 2.010995
# iteration 1500 / 2000: loss 2.015197
# iteration 1600 / 2000: loss 1.984303
# iteration 1700 / 2000: loss 2.004990
# iteration 1800 / 2000: loss 2.038345
# iteration 1900 / 2000: loss 1.990718
# Training Softmax 10 / 24 with learning_rate=2.000000e-03 and reg=1.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.194426
# iteration 200 / 2000: loss 2.210459
# iteration 300 / 2000: loss 2.209710
# iteration 400 / 2000: loss 2.212204
# iteration 500 / 2000: loss 2.304600
# iteration 600 / 2000: loss 2.279935
# iteration 700 / 2000: loss 2.280379
# iteration 800 / 2000: loss 2.301771
# iteration 900 / 2000: loss 2.355751
# iteration 1000 / 2000: loss 2.435357
# iteration 1100 / 2000: loss 2.464090
# iteration 1200 / 2000: loss 2.555037
# iteration 1300 / 2000: loss 2.549647
# iteration 1400 / 2000: loss 2.662375
# iteration 1500 / 2000: loss 2.714766
# iteration 1600 / 2000: loss 2.728834
# iteration 1700 / 2000: loss 2.795834
# iteration 1800 / 2000: loss 2.874056
# iteration 1900 / 2000: loss 2.872568
# Training Softmax 11 / 24 with learning_rate=2.000000e-03 and reg=2.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.223240
# iteration 200 / 2000: loss 2.285316
# iteration 300 / 2000: loss 2.334781
# iteration 400 / 2000: loss 2.390445
# iteration 500 / 2000: loss 2.534923
# iteration 600 / 2000: loss 2.564872
# iteration 700 / 2000: loss 2.619905
# iteration 800 / 2000: loss 2.694252
# iteration 900 / 2000: loss 2.801318
# iteration 1000 / 2000: loss 2.931320
# iteration 1100 / 2000: loss 3.011567
# iteration 1200 / 2000: loss 3.153116
# iteration 1300 / 2000: loss 3.195488
# iteration 1400 / 2000: loss 3.356513
# iteration 1500 / 2000: loss 3.458186
# iteration 1600 / 2000: loss 3.517759
# iteration 1700 / 2000: loss 3.631523
# iteration 1800 / 2000: loss 3.754667
# iteration 1900 / 2000: loss 3.799235
# Training Softmax 12 / 24 with learning_rate=2.000000e-03 and reg=1.000000e+01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.450082
# iteration 200 / 2000: loss 2.865994
# iteration 300 / 2000: loss 3.291431
# iteration 400 / 2000: loss 3.734923
# iteration 500 / 2000: loss 4.247883
# iteration 600 / 2000: loss 4.655555
# iteration 700 / 2000: loss 5.077444
# iteration 800 / 2000: loss 5.496512
# iteration 900 / 2000: loss 5.940890
# iteration 1000 / 2000: loss 6.378433
# iteration 1100 / 2000: loss 6.767793
# iteration 1200 / 2000: loss 7.203340
# iteration 1300 / 2000: loss 7.511301
# iteration 1400 / 2000: loss 7.936607
# iteration 1500 / 2000: loss 8.303249
# iteration 1600 / 2000: loss 8.594180
# iteration 1700 / 2000: loss 8.944106
# iteration 1800 / 2000: loss 9.283815
# iteration 1900 / 2000: loss 9.547988
# Training Softmax 13 / 24 with learning_rate=5.000000e-03 and reg=1.000000e-01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.100040
# iteration 200 / 2000: loss 2.082689
# iteration 300 / 2000: loss 2.036436
# iteration 400 / 2000: loss 2.011792
# iteration 500 / 2000: loss 2.056480
# iteration 600 / 2000: loss 1.968629
# iteration 700 / 2000: loss 1.933293
# iteration 800 / 2000: loss 1.902705
# iteration 900 / 2000: loss 1.933079
# iteration 1000 / 2000: loss 1.963299
# iteration 1100 / 2000: loss 1.955301
# iteration 1200 / 2000: loss 2.020398
# iteration 1300 / 2000: loss 1.952593
# iteration 1400 / 2000: loss 2.043974
# iteration 1500 / 2000: loss 2.049939
# iteration 1600 / 2000: loss 2.008857
# iteration 1700 / 2000: loss 2.048745
# iteration 1800 / 2000: loss 2.111918
# iteration 1900 / 2000: loss 2.065787
# Training Softmax 14 / 24 with learning_rate=5.000000e-03 and reg=1.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.192390
# iteration 200 / 2000: loss 2.293347
# iteration 300 / 2000: loss 2.372404
# iteration 400 / 2000: loss 2.475629
# iteration 500 / 2000: loss 2.639097
# iteration 600 / 2000: loss 2.672622
# iteration 700 / 2000: loss 2.754959
# iteration 800 / 2000: loss 2.833928
# iteration 900 / 2000: loss 2.972149
# iteration 1000 / 2000: loss 3.106759
# iteration 1100 / 2000: loss 3.204185
# iteration 1200 / 2000: loss 3.371756
# iteration 1300 / 2000: loss 3.398955
# iteration 1400 / 2000: loss 3.585404
# iteration 1500 / 2000: loss 3.689614
# iteration 1600 / 2000: loss 3.738891
# iteration 1700 / 2000: loss 3.869891
# iteration 1800 / 2000: loss 4.021162
# iteration 1900 / 2000: loss 4.065709
# Training Softmax 15 / 24 with learning_rate=5.000000e-03 and reg=2.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.294184
# iteration 200 / 2000: loss 2.523808
# iteration 300 / 2000: loss 2.737269
# iteration 400 / 2000: loss 2.975693
# iteration 500 / 2000: loss 3.262596
# iteration 600 / 2000: loss 3.420808
# iteration 700 / 2000: loss 3.622072
# iteration 800 / 2000: loss 3.809719
# iteration 900 / 2000: loss 4.053530
# iteration 1000 / 2000: loss 4.288542
# iteration 1100 / 2000: loss 4.486378
# iteration 1200 / 2000: loss 4.749872
# iteration 1300 / 2000: loss 4.863863
# iteration 1400 / 2000: loss 5.136413
# iteration 1500 / 2000: loss 5.328951
# iteration 1600 / 2000: loss 5.457003
# iteration 1700 / 2000: loss 5.667042
# iteration 1800 / 2000: loss 5.892870
# iteration 1900 / 2000: loss 6.013910
# Training Softmax 16 / 24 with learning_rate=5.000000e-03 and reg=1.000000e+01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 3.078360
# iteration 200 / 2000: loss 4.237822
# iteration 300 / 2000: loss 5.360523
# iteration 400 / 2000: loss 6.452680
# iteration 500 / 2000: loss 7.455332
# iteration 600 / 2000: loss 8.299263
# iteration 700 / 2000: loss 9.102944
# iteration 800 / 2000: loss 9.789899
# iteration 900 / 2000: loss 10.489886
# iteration 1000 / 2000: loss 11.117392
# iteration 1100 / 2000: loss 11.693560
# iteration 1200 / 2000: loss 12.284108
# iteration 1300 / 2000: loss 12.649255
# iteration 1400 / 2000: loss 13.166085
# iteration 1500 / 2000: loss 13.604851
# iteration 1600 / 2000: loss 13.903009
# iteration 1700 / 2000: loss 14.290492
# iteration 1800 / 2000: loss 14.647820
# iteration 1900 / 2000: loss 14.912564
# Training Softmax 17 / 24 with learning_rate=1.000000e-02 and reg=1.000000e-01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.050297
# iteration 200 / 2000: loss 2.051568
# iteration 300 / 2000: loss 2.013419
# iteration 400 / 2000: loss 2.019925
# iteration 500 / 2000: loss 2.067146
# iteration 600 / 2000: loss 1.983001
# iteration 700 / 2000: loss 1.951838
# iteration 800 / 2000: loss 1.938049
# iteration 900 / 2000: loss 1.992255
# iteration 1000 / 2000: loss 2.020469
# iteration 1100 / 2000: loss 2.036026
# iteration 1200 / 2000: loss 2.117034
# iteration 1300 / 2000: loss 2.038711
# iteration 1400 / 2000: loss 2.146015
# iteration 1500 / 2000: loss 2.163187
# iteration 1600 / 2000: loss 2.122848
# iteration 1700 / 2000: loss 2.173284
# iteration 1800 / 2000: loss 2.254742
# iteration 1900 / 2000: loss 2.217665
# Training Softmax 18 / 24 with learning_rate=1.000000e-02 and reg=1.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.265693
# iteration 200 / 2000: loss 2.512139
# iteration 300 / 2000: loss 2.722144
# iteration 400 / 2000: loss 2.966010
# iteration 500 / 2000: loss 3.220542
# iteration 600 / 2000: loss 3.345303
# iteration 700 / 2000: loss 3.512703
# iteration 800 / 2000: loss 3.677426
# iteration 900 / 2000: loss 3.905534
# iteration 1000 / 2000: loss 4.105641
# iteration 1100 / 2000: loss 4.294340
# iteration 1200 / 2000: loss 4.539334
# iteration 1300 / 2000: loss 4.610668
# iteration 1400 / 2000: loss 4.865670
# iteration 1500 / 2000: loss 5.038196
# iteration 1600 / 2000: loss 5.139329
# iteration 1700 / 2000: loss 5.327627
# iteration 1800 / 2000: loss 5.545098
# iteration 1900 / 2000: loss 5.645830
# Training Softmax 19 / 24 with learning_rate=1.000000e-02 and reg=2.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.501338
# iteration 200 / 2000: loss 3.008638
# iteration 300 / 2000: loss 3.475446
# iteration 400 / 2000: loss 3.957537
# iteration 500 / 2000: loss 4.412307
# iteration 600 / 2000: loss 4.734637
# iteration 700 / 2000: loss 5.083422
# iteration 800 / 2000: loss 5.404277
# iteration 900 / 2000: loss 5.780493
# iteration 1000 / 2000: loss 6.122946
# iteration 1100 / 2000: loss 6.452075
# iteration 1200 / 2000: loss 6.824607
# iteration 1300 / 2000: loss 7.005791
# iteration 1400 / 2000: loss 7.367058
# iteration 1500 / 2000: loss 7.650800
# iteration 1600 / 2000: loss 7.845675
# iteration 1700 / 2000: loss 8.123944
# iteration 1800 / 2000: loss 8.425805
# iteration 1900 / 2000: loss 8.611756
# Training Softmax 20 / 24 with learning_rate=1.000000e-02 and reg=1.000000e+01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 4.253884
# iteration 200 / 2000: loss 6.459478
# iteration 300 / 2000: loss 8.389934
# iteration 400 / 2000: loss 10.038160
# iteration 500 / 2000: loss 11.289696
# iteration 600 / 2000: loss 12.333295
# iteration 700 / 2000: loss 13.220985
# iteration 800 / 2000: loss 13.883187
# iteration 900 / 2000: loss 14.541701
# iteration 1000 / 2000: loss 15.107128
# iteration 1100 / 2000: loss 15.641514
# iteration 1200 / 2000: loss 16.128934
# iteration 1300 / 2000: loss 16.320661
# iteration 1400 / 2000: loss 16.701945
# iteration 1500 / 2000: loss 17.034622
# iteration 1600 / 2000: loss 17.165653
# iteration 1700 / 2000: loss 17.421174
# iteration 1800 / 2000: loss 17.638017
# iteration 1900 / 2000: loss 17.784103
# Training Softmax 21 / 24 with learning_rate=2.000000e-02 and reg=1.000000e-01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.016971
# iteration 200 / 2000: loss 2.051801
# iteration 300 / 2000: loss 2.032160
# iteration 400 / 2000: loss 2.075115
# iteration 500 / 2000: loss 2.136867
# iteration 600 / 2000: loss 2.072829
# iteration 700 / 2000: loss 2.044272
# iteration 800 / 2000: loss 2.065971
# iteration 900 / 2000: loss 2.140676
# iteration 1000 / 2000: loss 2.179741
# iteration 1100 / 2000: loss 2.223145
# iteration 1200 / 2000: loss 2.322756
# iteration 1300 / 2000: loss 2.237823
# iteration 1400 / 2000: loss 2.368690
# iteration 1500 / 2000: loss 2.402480
# iteration 1600 / 2000: loss 2.373770
# iteration 1700 / 2000: loss 2.441996
# iteration 1800 / 2000: loss 2.533972
# iteration 1900 / 2000: loss 2.515781
# Training Softmax 22 / 24 with learning_rate=2.000000e-02 and reg=1.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.488549
# iteration 200 / 2000: loss 2.992030
# iteration 300 / 2000: loss 3.417880
# iteration 400 / 2000: loss 3.859787
# iteration 500 / 2000: loss 4.253327
# iteration 600 / 2000: loss 4.523315
# iteration 700 / 2000: loss 4.805763
# iteration 800 / 2000: loss 5.095283
# iteration 900 / 2000: loss 5.428830
# iteration 1000 / 2000: loss 5.728451
# iteration 1100 / 2000: loss 6.034977
# iteration 1200 / 2000: loss 6.371423
# iteration 1300 / 2000: loss 6.497056
# iteration 1400 / 2000: loss 6.830293
# iteration 1500 / 2000: loss 7.087463
# iteration 1600 / 2000: loss 7.252201
# iteration 1700 / 2000: loss 7.501357
# iteration 1800 / 2000: loss 7.776524
# iteration 1900 / 2000: loss 7.936235
# Training Softmax 23 / 24 with learning_rate=2.000000e-02 and reg=2.000000e+00
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.996838
# iteration 200 / 2000: loss 3.977278
# iteration 300 / 2000: loss 4.831767
# iteration 400 / 2000: loss 5.632586
# iteration 500 / 2000: loss 6.299252
# iteration 600 / 2000: loss 6.835141
# iteration 700 / 2000: loss 7.345705
# iteration 800 / 2000: loss 7.810308
# iteration 900 / 2000: loss 8.303716
# iteration 1000 / 2000: loss 8.758367
# iteration 1100 / 2000: loss 9.214671
# iteration 1200 / 2000: loss 9.668885
# iteration 1300 / 2000: loss 9.881515
# iteration 1400 / 2000: loss 10.292496
# iteration 1500 / 2000: loss 10.644145
# iteration 1600 / 2000: loss 10.868023
# iteration 1700 / 2000: loss 11.169770
# iteration 1800 / 2000: loss 11.492446
# iteration 1900 / 2000: loss 11.697281
# Training Softmax 24 / 24 with learning_rate=2.000000e-02 and reg=1.000000e+01
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 6.526721
# iteration 200 / 2000: loss 10.015972
# iteration 300 / 2000: loss 12.581775
# iteration 400 / 2000: loss 14.357864
# iteration 500 / 2000: loss 15.369886
# iteration 600 / 2000: loss 16.263659
# iteration 700 / 2000: loss 16.840958
# iteration 800 / 2000: loss 17.130992
# iteration 900 / 2000: loss 17.466445
# iteration 1000 / 2000: loss 17.797818
# iteration 1100 / 2000: loss 18.142844
# iteration 1200 / 2000: loss 18.372608
# iteration 1300 / 2000: loss 18.266619
# iteration 1400 / 2000: loss 18.414822
# iteration 1500 / 2000: loss 18.642156
# iteration 1600 / 2000: loss 18.555671
# iteration 1700 / 2000: loss 18.711957
# iteration 1800 / 2000: loss 18.789858
# iteration 1900 / 2000: loss 18.857597
# lr 1.000000e-04 reg 1.000000e-01 train accuracy: 0.265450 val accuracy: 0.265700
# lr 1.000000e-04 reg 1.000000e+00 train accuracy: 0.265425 val accuracy: 0.265700
# lr 1.000000e-04 reg 2.000000e+00 train accuracy: 0.265450 val accuracy: 0.265700
# lr 1.000000e-04 reg 1.000000e+01 train accuracy: 0.265400 val accuracy: 0.265700
# lr 1.000000e-03 reg 1.000000e-01 train accuracy: 0.343225 val accuracy: 0.336400
# lr 1.000000e-03 reg 1.000000e+00 train accuracy: 0.342975 val accuracy: 0.336400
# lr 1.000000e-03 reg 2.000000e+00 train accuracy: 0.342600 val accuracy: 0.336200
# lr 1.000000e-03 reg 1.000000e+01 train accuracy: 0.340925 val accuracy: 0.333700
# lr 2.000000e-03 reg 1.000000e-01 train accuracy: 0.368175 val accuracy: 0.356500
# lr 2.000000e-03 reg 1.000000e+00 train accuracy: 0.367600 val accuracy: 0.356500
# lr 2.000000e-03 reg 2.000000e+00 train accuracy: 0.367150 val accuracy: 0.356500
# lr 2.000000e-03 reg 1.000000e+01 train accuracy: 0.361400 val accuracy: 0.352700
# lr 5.000000e-03 reg 1.000000e-01 train accuracy: 0.391750 val accuracy: 0.377100
# lr 5.000000e-03 reg 1.000000e+00 train accuracy: 0.390600 val accuracy: 0.376200
# lr 5.000000e-03 reg 2.000000e+00 train accuracy: 0.389300 val accuracy: 0.375300
# lr 5.000000e-03 reg 1.000000e+01 train accuracy: 0.380450 val accuracy: 0.368600
# lr 1.000000e-02 reg 1.000000e-01 train accuracy: 0.406575 val accuracy: 0.390500
# lr 1.000000e-02 reg 1.000000e+00 train accuracy: 0.405450 val accuracy: 0.388200
# lr 1.000000e-02 reg 2.000000e+00 train accuracy: 0.403650 val accuracy: 0.385500
# lr 1.000000e-02 reg 1.000000e+01 train accuracy: 0.387500 val accuracy: 0.373000
# lr 2.000000e-02 reg 1.000000e-01 train accuracy: 0.417550 val accuracy: 0.400300
# lr 2.000000e-02 reg 1.000000e+00 train accuracy: 0.414025 val accuracy: 0.397000
# lr 2.000000e-02 reg 2.000000e+00 train accuracy: 0.410525 val accuracy: 0.393900
# lr 2.000000e-02 reg 1.000000e+01 train accuracy: 0.387600 val accuracy: 0.375100
# best validation accuracy achieved during cross-validation: 0.400300
# Saved in drive/My Drive/A2/softmax_best_model.pt

# %% [markdown]
# Run the following to visualize your cross-validation results:

# %%
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')
plt.gcf().set_size_inches(8, 5)
plt.show()

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.gcf().set_size_inches(8, 5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1982741659.py in <cell line: 0>()
#       5 marker_size = 100
#       6 colors = [results[x][0] for x in results]
# ----> 7 plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
#       8 plt.colorbar()
#       9 plt.xlabel('log learning rate')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3937     **kwargs,
#    3938 ) -> PathCollection:
# -> 3939     __ret = gca().scatter(
#    3940         x,
#    3941         y,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4916             orig_edgecolor = kwargs.get('edgecolor', None)
#    4917         c, colors, edgecolors = \
# -> 4918             self._parse_scatter_color_args(
#    4919                 c, edgecolors, kwargs, x.size,
#    4920                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4695         if not c_was_none and kwcolor is None and not c_is_string_or_strings:
#    4696             try:  # First, does 'c' look suitable for value-mapping?
# -> 4697                 c = np.asanyarray(c, dtype=float)
#    4698             except ValueError:
#    4699                 pass  # Failed to convert to float array; must be color specs.
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in __array__(self, dtype)
#    1211             return self.numpy()
#    1212         else:
# -> 1213             return self.numpy().astype(dtype, copy=False)
#    1214
#    1215     # Wrap Numpy array again in a suitable tensor when done, to support e.g.
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %% [markdown]
# Them, evaluate the performance of your best model on test set. To get full credit for this assignment you should achieve a test-set accuracy above 0.36.
#
# (Our best was just around 39.9% -- did you beat us?)

# %%
y_test_pred = best_softmax_model.predict(data_dict['X_test'])
test_accuracy = torch.mean((data_dict['y_test'] == y_test_pred).double())
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.404400

# %% [markdown]
# Finally, let's visualize the learned weights for each class

# %%
w = best_softmax_model.W[:-1,:] # strip out the bias
w = w.reshape(3, 32, 32, 10)
w = w.transpose(0, 2).transpose(1, 0)

w_min, w_max = torch.min(w), torch.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
  plt.subplot(2, 5, i + 1)

  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.type(torch.uint8).cpu())
  plt.axis('off')
  plt.title(classes[i])
